# %% [markdown]
# ## Predicting the NBA Finals MVP with ML
# #### *by Noah Ford*

# %% [markdown]
# #### Importing Packages and Helper Functions

# %% [markdown]
# I've outsourced most of the importing of tools and helper functions of an accompanying workbook [helper_funcs.ipynb](helper_funcs.ipynb).

# %%
# %run helper_funcs.ipynb
print('success!')
# Out:
# success!

# %% [markdown]
# #### Getting Set Up

# %% [markdown]
# Here we'll set up the paths to the data we will access throughout.

# %%
DIR = 'series'
DIR2 = 'csvs'

# %% [markdown]
# The first jumping off point for this notebook, is getting access to the playoff history.  We will use [basketball-reference.com](https://www.basketball-reference.com) for the entirety of our data accessing. \
# This first link we're accessing takes us to a page with information for every playoff series: winner, loser, finals mvp, hyperlinks to more stats, etc.

# %% [markdown]
# ## Data Scraping

# %%
BASE = "https://www.basketball-reference.com"
url = "https://www.basketball-reference.com/playoffs/series.html"
# save takes a path and a folder, and fetches the html we're looking for
text = save(url,DIR)
bs = BeautifulSoup(text, 'html.parser')
table = bs.find(id = 'div_playoffs_series')

# %% [markdown]
# This below function wraps up that above code into a nice callable unit.

# %%
def get_html_table():
    url = "https://www.basketball-reference.com/playoffs/series.html"
    text = save(url,DIR)
    bs = BeautifulSoup(text, 'html.parser')
    table = bs.find(id = 'div_playoffs_series')
    return table

# %% [markdown]
# playoff_history just is a wrapper for the pandas native function read_html, which when given html, spits out a dataframe.

# %%
def playoff_history(url,header_col=False):
    p = os.path.join(DIR2, name_csv(url))
    if not(os.path.exists(p)):
        text = save(url,DIR2)
        bs = BeautifulSoup(text, 'html.parser')
        df = pd.read_html(url)[0]
        if header_col: df.columns = df.columns.get_level_values(1)
        df.to_csv(p,index=True)
    else :
        df = pd.read_csv(p,index_col=0)
    return df

# %%
url = "https://www.basketball-reference.com/playoffs/series.html"
t = playoff_history(url,True)

# %% [markdown]
# We'll just do a bit of cleaning to drop some unneeded columns.  Additionally, we only care about finals history.

# %%
def playoff_history_cleaned():
    url = "https://www.basketball-reference.com/playoffs/series.html"
    df = playoff_history(url,True)
    df.drop(df.columns[[4,7,10,-2,-1]], axis=1, inplace=True)
    df['Yr'] = pd.to_numeric(df['Yr'], errors='coerce').fillna(0).astype(int)
    df = df[df['Lg'].str.contains('NBA', na=False)].reset_index(drop=True)
    df = df[df['Yr']>1968].reset_index(drop=True)
    df = df[~df['Series'].str.contains('Conf', na=True)].reset_index(drop=True)
    df = df[~df['Series'].str.contains('Semi', na=False)].reset_index(drop=True)
    df = df[~df['Series'].str.contains('Div', na=False)].reset_index(drop=True)
    return df

# %%
playoff_history_cleaned().head(5)
# Out:
#      Yr   Lg  Series     Unnamed: 3_level_1                       Team  W  \
# 0  2024  NBA  Finals   Jun 6 - Jun 17, 2024         Boston Celtics (1)  4
# 1  2023  NBA  Finals   Jun 1 - Jun 12, 2023         Denver Nuggets (1)  4
# 2  2022  NBA  Finals   Jun 2 - Jun 16, 2022  Golden State Warriors (3)  4
# 3  2021  NBA  Finals   Jul 6 - Jul 20, 2021        Milwaukee Bucks (3)  4
# 4  2020  NBA  Finals  Sep 30 - Oct 11, 2020     Los Angeles Lakers (1)  4
#
#                  Team.1 W.1
# 0  Dallas Mavericks (5)   1
# 1        Miami Heat (8)   1
# 2    Boston Celtics (2)   2
# 3      Phoenix Suns (2)   2
# 4        Miami Heat (5)   2

# %% [markdown]
# I've stored the finals MVP history into an existing csv, so we can actually look at that using our same playoff_history function, just passing that different file path.

# %%
url = 'https://www.basketball-reference.com/awards/finals_mvp.html'
df = playoff_history('csvs/finals_mvp.csv',True)
df.head(5)
# Out:
#     Season   Lg                 Player  Age   Tm  G    MP   PTS   TRB  AST  \
# 0  2023-24  NBA           Jaylen Brown   27  BOS  5  38.6  20.8   5.4  5.0
# 1  2022-23  NBA           Nikola Jokic   27  DEN  5  41.2  30.2  14.0  7.2
# 2  2021-22  NBA          Stephen Curry   33  GSW  6  37.5  31.2   6.0  5.0
# 3  2020-21  NBA  Giannis Antetokounmpo   26  MIL  6  39.8  35.2  13.2  5.0
# 4  2019-20  NBA           LeBron James   35  LAL  6  39.3  29.8  11.8  8.5
#
#    STL  BLK    FG%    3P%    FT%
# 0  1.6  0.8  0.440  0.235  0.733
# 1  0.8  1.4  0.583  0.421  0.838
# 2  2.0  0.2  0.482  0.437  0.857
# 3  1.2  1.8  0.618  0.200  0.659
# 4  1.2  0.5  0.591  0.417  0.667

# %% [markdown]
# Now we would like to merge the finals history dataframe, the finals mvp dataframe, and a dataframe of hyperlinks into the series summary of each dataframe.

# %% [markdown]
# That last one is the trickiest to get because the links do not populate in the finals history dataframe from our read_html call.  So, we have to perform a workaround to read through the html directly.

# %%
def add_mvp():
    df = pd.read_csv('csvs/finals_mvp.csv',index_col=0)
    return df

# %%
def hyperlink_table():
    table = get_html_table()
    series = [tag for tag in table.find_all('a') if "vs" in tag['href']]
    recent = [tag for tag in series if int(tag['href'].split("/")[2].split("-")[0]) > 1968]
    hrefs = [BASE + a['href'] for a in recent]
    col = [tag for tag in hrefs if 'nba-finals' in tag]
    col = pd.DataFrame(col, columns=["url"])
    return col

# %%
def merged_table():
    # ret = await get_html(url,"#div_playoffs_series")
    table = get_html_table()
    df = playoff_history_cleaned()
    col = hyperlink_table()
    full = pd.concat([df,add_mvp()],axis = 1)
    full = pd.concat([full,col],axis = 1)
    return full

# %%
FULL_DF = merged_table()
FULL_DF.head(5)
# Out:
#      Yr   Lg  Series     Unnamed: 3_level_1                       Team  W  \
# 0  2024  NBA  Finals   Jun 6 - Jun 17, 2024         Boston Celtics (1)  4
# 1  2023  NBA  Finals   Jun 1 - Jun 12, 2023         Denver Nuggets (1)  4
# 2  2022  NBA  Finals   Jun 2 - Jun 16, 2022  Golden State Warriors (3)  4
# 3  2021  NBA  Finals   Jul 6 - Jul 20, 2021        Milwaukee Bucks (3)  4
# 4  2020  NBA  Finals  Sep 30 - Oct 11, 2020     Los Angeles Lakers (1)  4
#
#                  Team.1 W.1   Season   Lg  ...    MP   PTS   TRB  AST  STL  \
# 0  Dallas Mavericks (5)   1  2023-24  NBA  ...  38.6  20.8   5.4  5.0  1.6
# 1        Miami Heat (8)   1  2022-23  NBA  ...  41.2  30.2  14.0  7.2  0.8
# 2    Boston Celtics (2)   2  2021-22  NBA  ...  37.5  31.2   6.0  5.0  2.0
# 3      Phoenix Suns (2)   2  2020-21  NBA  ...  39.8  35.2  13.2  5.0  1.2
# 4        Miami Heat (5)   2  2019-20  NBA  ...  39.3  29.8  11.8  8.5  1.2
#
#    BLK    FG%    3P%    FT%                                                url
# 0  0.8  0.440  0.235  0.733  https://www.basketball-reference.com/playoffs/...
# 1  1.4  0.583  0.421  0.838  https://www.basketball-reference.com/playoffs/...
# 2  0.2  0.482  0.437  0.857  https://www.basketball-reference.com/playoffs/...
# 3  1.8  0.618  0.200  0.659  https://www.basketball-reference.com/playoffs/...
# 4  0.5  0.591  0.417  0.667  https://www.basketball-reference.com/playoffs/...
#
# [5 rows x 24 columns]

# %%
def winner_abbrev(url):
    bs = BeautifulSoup(save(url,DIR))
    ref = [link['href'] for link in bs.find_all('a') if 'teams' in link['href'] and '.html' in link['href']][0]
    return ref.split('/')[2]

# %%
winner_abbrev(FULL_DF['url'][0])
# Out:
# 'BOS'

# %% [markdown]
# We enter into some dicey territory here because for some reason, basketball reference was keeping their accessible playoff series stats only in the form of a comment.  Meaning, we have to convert the comment into usable html before we can proceed.

# %% [markdown]
# The reason we wrote the winner_abbrev functions above is because the boxscores are ordered not by who won, but rather who was home.  Meaning, when we're searching the page, we have to introduce logic to jump to the correct box score.  We achieve that here by pulling the abbreviation of each team, which is then used to label the box scores in the id.

# %%
def save_table(url):
    p = os.path.join(DIR2, name_csv(url))
    if not(os.path.exists(p)):
        save_tag(url,DIR,f'all_{winner_abbrev(url)}')
        text = save_tag(url,DIR,f'all_{winner_abbrev(url)}')
        bs = BeautifulSoup(text, 'html.parser')
        # table = bs.find(id = f'div_{winner_abbrev(url)}')
        # Find all comments
        comments = bs.find_all(string=lambda text: isinstance(text, Comment))
        table_c = [c for c in comments if len(c) > 10000][0]
        comment_soup = BeautifulSoup(table_c, 'html.parser')
        table = comment_soup.find('table')
        df = pd.read_html(str(table))[0]
        df.columns = df.columns.get_level_values(1)
        df.drop(df.columns[[0]], axis=1, inplace=True)
        df.to_csv(p)
        with open(p, "w+") as f:
            f.write(df.to_csv(p))
    else :
        df = pd.read_csv(p)
        df.drop(df.columns[[0]], axis=1, inplace=True)
    return df

# %% [markdown]
# Here I want to optimize the retrieval of our html information, so I'll plop that all into csvs which will be easier to access than the htmls.

# %%
def get_table(url):
    p = os.path.join(DIR2, name_csv(url))
    df = pd.read_csv(p)
    df.drop(df.columns[[0]], axis=1, inplace=True)
    return df

# %%
for link in tqdm(FULL_DF['url']):
    try:
        save_table(link)
    except:
        save_table(link)
# Out:
# 100%|██████████| 56/56 [00:00<00:00, 1223.13it/s]

# %%
url = FULL_DF['url'][2]
get_table(url).head(5)
# Out:
#            Player   Age  G   MP  FG  FGA  3P  3PA  FT  FTA  ...  PTS    FG%  \
# 0   Stephen Curry  33.0  6  225  66  137  31   71  24   28  ...  187  0.482
# 1  Andrew Wiggins  26.0  6  235  45  101  11   37   9   13  ...  110  0.446
# 2   Klay Thompson  31.0  6  230  36  101  20   57  10   10  ...  102  0.356
# 3    Jordan Poole  22.0  6  125  27   62  15   39  10   11  ...   79  0.435
# 4  Draymond Green  31.0  6  217  14   42   2   16   7   12  ...   37  0.333
#
#      3P%    FT%  MP.1  PTS.1  TRB.1  AST.1  STL.1  BLK.1
# 0  0.437  0.857  37.5   31.2    6.0    5.0    2.0    0.2
# 1  0.297  0.692  39.2   18.3    8.8    2.2    1.5    1.5
# 2  0.351  1.000  38.3   17.0    3.0    2.0    1.3    0.5
# 3  0.385  0.909  20.8   13.2    1.8    1.8    0.5    0.2
# 4  0.125  0.583  36.2    6.2    8.0    6.2    1.7    0.7
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# Now we're almost there!  We now just need to clean up our data to make nice integers and floats for the machine learning models to read.

# %%
def clean_table(url):
    t = get_table(url)
    mvp = mvp_from_url(url)
    t.drop(t.columns[[1,5,7,9,-6,-5,-4,-3,-2,-1]], axis=1, inplace=True)
    t = t.drop(t.index[-1])
    yr = year_from_url(url)
    t['3P'] = pd.to_numeric(t['3P'], errors='coerce').fillna(0).astype(int)
    t['FG%'] = pd.to_numeric(t['FG%'], errors='coerce').fillna(0).astype(float)
    t['3P%'] = pd.to_numeric(t['3P%'], errors='coerce').fillna(0).astype(float)
    t['FT%'] = pd.to_numeric(t['FT%'], errors='coerce').fillna(0).astype(float)
    t['STL'] = pd.to_numeric(t['STL'], errors='coerce').fillna(0).astype(int)
    t['BLK'] = pd.to_numeric(t['BLK'], errors='coerce').fillna(0).astype(int)
    t['ORB'] = pd.to_numeric(t['ORB'], errors='coerce').fillna(0).astype(int)
    t['DRB'] = pd.to_numeric(t['DRB'], errors='coerce').fillna(0).astype(int)
    t['TOV'] = pd.to_numeric(t['TOV'], errors='coerce').fillna(0).astype(int)
    # t['Age'] = pd.to_numeric(t['Age'], errors='coerce').fillna(0).astype(int)
    t['mvp'] = t['Player'].apply(lambda x: x == mvp)
    return t

# %% [markdown]
# A big picture ML decision I've made on this project is to label players statistics by their relative rank to their teammates.  Meaning, I'm not interested in knowing that player X who put a 30/6/5 should win MVP, because if that player had a teammate who put up 35/12/9, then we'd have to reconsider. \
# However, that is a potential follow up of this project.

# %%
def rank_table(t):
    # MP through blocks
    cols = t.columns[1:18]
    for i,col in enumerate(cols):
        new_name = col + '!'
        ascending_bool = (i == 11) or (i == 12)
        t[new_name] = t[col].rank(ascending=ascending_bool, method='min').astype(int)
        t.drop(columns = [col],inplace=True)
    return t

# %% [markdown]
# top_table takes just the top X entries from the table.  Meaning we don't care to predict Brian Scalabrine's chance at winning MVP.

# %%
def top_table(url,top):
    df = clean_table(url)
    df = df.drop(df.index[top:])
    df = rank_table(df)
    yr = year_from_url(url)
    df.insert(0,'Year',yr)
    return df

# %%
FULL_DF
# Out:
#       Yr   Lg  Series     Unnamed: 3_level_1                        Team  W  \
# 0   2024  NBA  Finals   Jun 6 - Jun 17, 2024          Boston Celtics (1)  4
# 1   2023  NBA  Finals   Jun 1 - Jun 12, 2023          Denver Nuggets (1)  4
# 2   2022  NBA  Finals   Jun 2 - Jun 16, 2022   Golden State Warriors (3)  4
# 3   2021  NBA  Finals   Jul 6 - Jul 20, 2021         Milwaukee Bucks (3)  4
# 4   2020  NBA  Finals  Sep 30 - Oct 11, 2020      Los Angeles Lakers (1)  4
# 5   2019  NBA  Finals  May 30 - Jun 13, 2019         Toronto Raptors (2)  4
# 6   2018  NBA  Finals   May 31 - Jun 8, 2018   Golden State Warriors (2)  4
# 7   2017  NBA  Finals   Jun 1 - Jun 12, 2017   Golden State Warriors (1)  4
# 8   2016  NBA  Finals   Jun 2 - Jun 19, 2016     Cleveland Cavaliers (1)  4
# 9   2015  NBA  Finals   Jun 4 - Jun 16, 2015   Golden State Warriors (1)  4
# 10  2014  NBA  Finals   Jun 5 - Jun 15, 2014       San Antonio Spurs (1)  4
# 11  2013  NBA  Finals   Jun 6 - Jun 20, 2013              Miami Heat (1)  4
# 12  2012  NBA  Finals  Jun 12 - Jun 21, 2012              Miami Heat (2)  4
# 13  2011  NBA  Finals  May 31 - Jun 12, 2011        Dallas Mavericks (3)  4
# 14  2010  NBA  Finals   Jun 3 - Jun 17, 2010      Los Angeles Lakers (1)  4
# 15  2009  NBA  Finals   Jun 4 - Jun 14, 2009      Los Angeles Lakers (1)  4
# 16  2008  NBA  Finals   Jun 5 - Jun 17, 2008          Boston Celtics (1)  4
# 17  2007  NBA  Finals   Jun 7 - Jun 14, 2007       San Antonio Spurs (3)  4
# 18  2006  NBA  Finals   Jun 8 - Jun 20, 2006              Miami Heat (2)  4
# 19  2005  NBA  Finals   Jun 9 - Jun 23, 2005       San Antonio Spurs (2)  4
# 20  2004  NBA  Finals   Jun 6 - Jun 15, 2004         Detroit Pistons (3)  4
# 21  2003  NBA  Finals   Jun 4 - Jun 15, 2003       San Antonio Spurs (1)  4
# 22  2002  NBA  Finals   Jun 5 - Jun 12, 2002      Los Angeles Lakers (3)  4
# 23  2001  NBA  Finals   Jun 6 - Jun 15, 2001      Los Angeles Lakers (2)  4
# 24  2000  NBA  Finals   Jun 7 - Jun 19, 2000      Los Angeles Lakers (1)  4
# 25  1999  NBA  Finals  Jun 16 - Jun 25, 1999       San Antonio Spurs (1)  4
# 26  1998  NBA  Finals   Jun 3 - Jun 14, 1998           Chicago Bulls (1)  4
# 27  1997  NBA  Finals   Jun 1 - Jun 13, 1997           Chicago Bulls (1)  4
# 28  1996  NBA  Finals   Jun 5 - Jun 16, 1996           Chicago Bulls (1)  4
# 29  1995  NBA  Finals   Jun 7 - Jun 14, 1995         Houston Rockets (6)  4
# 30  1994  NBA  Finals   Jun 8 - Jun 22, 1994         Houston Rockets (2)  4
# 31  1993  NBA  Finals   Jun 9 - Jun 20, 1993           Chicago Bulls (2)  4
# 32  1992  NBA  Finals   Jun 3 - Jun 14, 1992           Chicago Bulls (1)  4
# 33  1991  NBA  Finals   Jun 2 - Jun 12, 1991           Chicago Bulls (1)  4
# 34  1990  NBA  Finals   Jun 5 - Jun 14, 1990         Detroit Pistons (1)  4
# 35  1989  NBA  Finals   Jun 6 - Jun 13, 1989         Detroit Pistons (1)  4
# 36  1988  NBA  Finals   Jun 7 - Jun 21, 1988      Los Angeles Lakers (1)  4
# 37  1987  NBA  Finals   Jun 2 - Jun 14, 1987      Los Angeles Lakers (1)  4
# 38  1986  NBA  Finals   May 26 - Jun 8, 1986          Boston Celtics (1)  4
# 39  1985  NBA  Finals   May 27 - Jun 9, 1985      Los Angeles Lakers (1)  4
# 40  1984  NBA  Finals  May 27 - Jun 12, 1984          Boston Celtics (1)  4
# 41  1983  NBA  Finals  May 22 - May 31, 1983      Philadelphia 76ers (1)  4
# 42  1982  NBA  Finals   May 27 - Jun 8, 1982      Los Angeles Lakers (1)  4
# 43  1981  NBA  Finals   May 5 - May 14, 1981          Boston Celtics (1)  4
# 44  1980  NBA  Finals   May 4 - May 16, 1980      Los Angeles Lakers (1)  4
# 45  1979  NBA  Finals   May 20 - Jun 1, 1979     Seattle SuperSonics (1)  4
# 46  1978  NBA  Finals   May 21 - Jun 7, 1978      Washington Bullets (3)  4
# 47  1977  NBA  Finals   May 22 - Jun 5, 1977  Portland Trail Blazers (3)  4
# 48  1976  NBA  Finals   May 23 - Jun 6, 1976          Boston Celtics (1)  4
# 49  1975  NBA  Finals  May 18 - May 25, 1975   Golden State Warriors (1)  4
# 50  1974  NBA  Finals  Apr 28 - May 12, 1974          Boston Celtics (1)  4
# 51  1973  NBA  Finals   May 1 - May 10, 1973         New York Knicks (2)  4
# 52  1972  NBA  Finals   Apr 26 - May 7, 1972      Los Angeles Lakers (1)  4
# 53  1971  NBA  Finals  Apr 21 - Apr 30, 1971         Milwaukee Bucks (1)  4
# 54  1970  NBA  Finals   Apr 24 - May 8, 1970         New York Knicks (1)  4
# 55  1969  NBA  Finals   Apr 23 - May 5, 1969          Boston Celtics (4)  4
#
#                         Team.1 W.1   Season   Lg  ...    MP   PTS   TRB   AST  \
# 0         Dallas Mavericks (5)   1  2023-24  NBA  ...  38.6  20.8   5.4   5.0
# 1               Miami Heat (8)   1  2022-23  NBA  ...  41.2  30.2  14.0   7.2
# 2           Boston Celtics (2)   2  2021-22  NBA  ...  37.5  31.2   6.0   5.0
# 3             Phoenix Suns (2)   2  2020-21  NBA  ...  39.8  35.2  13.2   5.0
# 4               Miami Heat (5)   2  2019-20  NBA  ...  39.3  29.8  11.8   8.5
# 5    Golden State Warriors (1)   2  2018-19  NBA  ...  40.5  28.5   9.8   4.2
# 6      Cleveland Cavaliers (4)   0  2017-18  NBA  ...  41.3  28.8  10.8   7.5
# 7      Cleveland Cavaliers (2)   1  2016-17  NBA  ...  39.8  35.2   8.2   5.4
# 8    Golden State Warriors (1)   3  2015-16  NBA  ...  41.7  29.7  11.3   8.9
# 9      Cleveland Cavaliers (2)   2  2014-15  NBA  ...  37.0  16.3   5.8   4.0
# 10              Miami Heat (2)   1  2013-14  NBA  ...  33.4  17.8   6.4   2.0
# 11       San Antonio Spurs (2)   3  2012-13  NBA  ...  43.0  25.3  10.9   7.0
# 12   Oklahoma City Thunder (2)   1  2011-12  NBA  ...  44.0  28.6  10.2   7.4
# 13              Miami Heat (2)   2  2010-11  NBA  ...  40.3  26.0   9.7   2.0
# 14          Boston Celtics (4)   3  2009-10  NBA  ...  41.1  28.6   8.0   3.9
# 15           Orlando Magic (3)   1  2008-09  NBA  ...  43.8  32.4   5.6   7.4
# 16      Los Angeles Lakers (1)   2  2007-08  NBA  ...  38.8  21.8   4.5   6.3
# 17     Cleveland Cavaliers (2)   0  2006-07  NBA  ...  37.8  24.5   5.0   3.3
# 18        Dallas Mavericks (4)   2  2005-06  NBA  ...  43.5  34.7   7.8   3.8
# 19         Detroit Pistons (2)   3  2004-05  NBA  ...  40.7  20.6  14.1   2.1
# 20      Los Angeles Lakers (2)   1  2003-04  NBA  ...  38.8  21.0   3.2   5.2
# 21         New Jersey Nets (2)   2  2002-03  NBA  ...  44.0  24.2  17.0   5.3
# 22         New Jersey Nets (1)   0  2001-02  NBA  ...  41.5  36.3  12.3   3.8
# 23      Philadelphia 76ers (1)   1  2000-01  NBA  ...  45.0  33.0  15.8   4.8
# 24          Indiana Pacers (1)   2  1999-00  NBA  ...  45.7  38.0  16.7   2.3
# 25         New York Knicks (8)   1  1998-99  NBA  ...  45.6  27.4  14.0   2.4
# 26               Utah Jazz (1)   2  1997-98  NBA  ...  41.7  33.5   4.0   2.3
# 27               Utah Jazz (1)   2  1996-97  NBA  ...  42.7  32.3   7.0   6.0
# 28     Seattle SuperSonics (1)   2  1995-96  NBA  ...  42.0  27.3   5.3   4.2
# 29           Orlando Magic (1)   0  1994-95  NBA  ...  44.8  32.8  11.5   5.5
# 30         New York Knicks (2)   3  1993-94  NBA  ...  43.1  26.9   9.1   3.6
# 31            Phoenix Suns (1)   2  1992-93  NBA  ...  45.7  41.0   8.5   6.3
# 32  Portland Trail Blazers (1)   2  1991-92  NBA  ...  42.3  35.8   4.8   6.5
# 33      Los Angeles Lakers (3)   1  1990-91  NBA  ...  44.0  31.2   6.6  11.4
# 34  Portland Trail Blazers (3)   1  1989-90  NBA  ...  38.4  27.6   5.2   7.0
# 35      Los Angeles Lakers (1)   0  1988-89  NBA  ...  36.8  27.3   1.8   6.0
# 36         Detroit Pistons (2)   3  1987-88  NBA  ...  38.0  22.0   7.4   4.4
# 37          Boston Celtics (1)   2  1986-87  NBA  ...  39.3  26.2   8.0  13.0
# 38         Houston Rockets (2)   2  1985-86  NBA  ...  44.8  24.0   9.7   9.5
# 39          Boston Celtics (1)   2  1984-85  NBA  ...  35.5  25.7   9.0   5.2
# 40      Los Angeles Lakers (1)   3  1983-84  NBA  ...  43.6  27.4  14.0   3.6
# 41      Los Angeles Lakers (1)   0  1982-83  NBA  ...  39.3  25.8  18.0   2.0
# 42      Philadelphia 76ers (3)   2  1981-82  NBA  ...  41.7  16.2  10.8   8.0
# 43         Houston Rockets (6)   2  1980-81  NBA  ...  37.8  17.7   9.5   2.8
# 44      Philadelphia 76ers (3)   2  1979-80  NBA  ...  42.7  21.5  11.2   8.7
# 45      Washington Bullets (1)   1  1978-79  NBA  ...  44.8  22.6   6.0   6.0
# 46     Seattle SuperSonics (4)   3  1977-78  NBA  ...  38.6   9.0  11.7   3.9
# 47      Philadelphia 76ers (1)   2  1976-77  NBA  ...  37.7  18.5  19.0   5.2
# 48            Phoenix Suns (3)   2  1975-76  NBA  ...  46.5  21.7   4.3   5.8
# 49      Washington Bullets (2)   0  1974-75  NBA  ...  43.0  29.5   4.0   5.0
# 50         Milwaukee Bucks (1)   3  1973-74  NBA  ...  47.1  26.4   7.7   4.7
# 51      Los Angeles Lakers (2)   1  1972-73  NBA  ...  30.0  16.4   9.2   2.6
# 52         New York Knicks (2)   1  1971-72  NBA  ...  47.2  19.4  23.2   2.6
# 53       Baltimore Bullets (1)   0  1970-71  NBA  ...  42.0  27.0  18.5   2.8
# 54      Los Angeles Lakers (2)   3  1969-70  NBA  ...  37.7  23.0  10.5   2.8
# 55      Los Angeles Lakers (1)   3  1968-69  NBA  ...  43.9  37.9   4.7   7.4
#
#     STL  BLK    FG%    3P%    FT%  \
# 0   1.6  0.8  0.440  0.235  0.733
# 1   0.8  1.4  0.583  0.421  0.838
# 2   2.0  0.2  0.482  0.437  0.857
# 3   1.2  1.8  0.618  0.200  0.659
# 4   1.2  0.5  0.591  0.417  0.667
# 5   2.0  1.2  0.434  0.357  0.906
# 6   0.8  2.3  0.526  0.409  0.963
# 7   1.0  1.6  0.556  0.474  0.927
# 8   2.6  2.3  0.494  0.371  0.721
# 9   1.3  0.3  0.521  0.400  0.357
# 10  1.6  1.2  0.612  0.579  0.783
# 11  2.3  0.9  0.447  0.353  0.795
# 12  1.6  0.4  0.472  0.188  0.826
# 13  0.7  0.7  0.416  0.368  0.978
# 14  2.1  0.7  0.405  0.319  0.883
# 15  1.4  1.4  0.430  0.360  0.841
# 16  1.2  0.3  0.432  0.393  0.830
# 17  0.8  0.0  0.568  0.571  0.526
# 18  2.7  1.0  0.468  0.273  0.773
# 19  0.4  2.1  0.419    NaN  0.667
# 20  1.2  0.0  0.509  0.471  0.929
# 21  1.0  5.3  0.495  0.000  0.685
# 22  0.5  2.8  0.595    NaN  0.662
# 23  0.4  3.4  0.573    NaN  0.513
# 24  1.0  2.7  0.611    NaN  0.387
# 25  1.0  2.2  0.537  0.000  0.795
# 26  1.8  0.7  0.427  0.308  0.814
# 27  1.2  0.8  0.456  0.320  0.764
# 28  1.7  0.2  0.415  0.316  0.836
# 29  2.0  2.0  0.483  1.000  0.692
# 30  1.6  3.9  0.500  1.000  0.860
# 31  1.7  0.7  0.508  0.400  0.694
# 32  1.7  0.3  0.526  0.429  0.891
# 33  2.8  1.4  0.558  0.500  0.848
# 34  1.6  0.4  0.542  0.688  0.742
# 35  0.5  0.3  0.576  0.000  0.868
# 36  0.7  0.6  0.492  0.000  0.735
# 37  2.3  0.3  0.541  0.500  0.960
# 38  2.7  0.3  0.482  0.368  0.939
# 39  1.0  1.5  0.604    NaN  0.769
# 40  2.1  1.1  0.484  0.667  0.842
# 41  1.5  1.5  0.507    NaN  0.660
# 42  2.5  0.3  0.533  0.000  0.846
# 43  0.2  1.0  0.568    NaN  0.759
# 44  2.7  0.3  0.573  0.000  0.875
# 45  1.8  2.2  0.459    NaN  0.719
# 46  0.6  0.1  0.520    NaN  0.550
# 47  1.0  3.7  0.545    NaN  0.789
# 48  1.5  0.0  0.439    NaN  0.878
# 49  3.5  0.8  0.444    NaN  0.938
# 50  1.9  0.0  0.429    NaN  0.872
# 51  NaN  NaN  0.493    NaN  0.889
# 52  NaN  NaN  0.600    NaN  0.543
# 53  NaN  NaN  0.605    NaN  0.762
# 54  NaN  NaN  0.484    NaN  0.588
# 55  NaN  NaN  0.490    NaN  0.839
#
#                                                   url
# 0   https://www.basketball-reference.com/playoffs/...
# 1   https://www.basketball-reference.com/playoffs/...
# 2   https://www.basketball-reference.com/playoffs/...
# 3   https://www.basketball-reference.com/playoffs/...
# 4   https://www.basketball-reference.com/playoffs/...
# 5   https://www.basketball-reference.com/playoffs/...
# 6   https://www.basketball-reference.com/playoffs/...
# 7   https://www.basketball-reference.com/playoffs/...
# 8   https://www.basketball-reference.com/playoffs/...
# 9   https://www.basketball-reference.com/playoffs/...
# 10  https://www.basketball-reference.com/playoffs/...
# 11  https://www.basketball-reference.com/playoffs/...
# 12  https://www.basketball-reference.com/playoffs/...
# 13  https://www.basketball-reference.com/playoffs/...
# 14  https://www.basketball-reference.com/playoffs/...
# 15  https://www.basketball-reference.com/playoffs/...
# 16  https://www.basketball-reference.com/playoffs/...
# 17  https://www.basketball-reference.com/playoffs/...
# 18  https://www.basketball-reference.com/playoffs/...
# 19  https://www.basketball-reference.com/playoffs/...
# 20  https://www.basketball-reference.com/playoffs/...
# 21  https://www.basketball-reference.com/playoffs/...
# 22  https://www.basketball-reference.com/playoffs/...
# 23  https://www.basketball-reference.com/playoffs/...
# 24  https://www.basketball-reference.com/playoffs/...
# 25  https://www.basketball-reference.com/playoffs/...
# 26  https://www.basketball-reference.com/playoffs/...
# 27  https://www.basketball-reference.com/playoffs/...
# 28  https://www.basketball-reference.com/playoffs/...
# 29  https://www.basketball-reference.com/playoffs/...
# 30  https://www.basketball-reference.com/playoffs/...
# 31  https://www.basketball-reference.com/playoffs/...
# 32  https://www.basketball-reference.com/playoffs/...
# 33  https://www.basketball-reference.com/playoffs/...
# 34  https://www.basketball-reference.com/playoffs/...
# 35  https://www.basketball-reference.com/playoffs/...
# 36  https://www.basketball-reference.com/playoffs/...
# 37  https://www.basketball-reference.com/playoffs/...
# 38  https://www.basketball-reference.com/playoffs/...
# 39  https://www.basketball-reference.com/playoffs/...
# 40  https://www.basketball-reference.com/playoffs/...
# 41  https://www.basketball-reference.com/playoffs/...
# 42  https://www.basketball-reference.com/playoffs/...
# 43  https://www.basketball-reference.com/playoffs/...
# 44  https://www.basketball-reference.com/playoffs/...
# 45  https://www.basketball-reference.com/playoffs/...
# 46  https://www.basketball-reference.com/playoffs/...
# 47  https://www.basketball-reference.com/playoffs/...
# 48  https://www.basketball-reference.com/playoffs/...
# 49  https://www.basketball-reference.com/playoffs/...
# 50  https://www.basketball-reference.com/playoffs/...
# 51  https://www.basketball-reference.com/playoffs/...
# 52  https://www.basketball-reference.com/playoffs/...
# 53  https://www.basketball-reference.com/playoffs/...
# 54  https://www.basketball-reference.com/playoffs/...
# 55  https://www.basketball-reference.com/playoffs/...
#
# [56 rows x 24 columns]

# %%
top_table(FULL_DF['url'][0],8)
# Out:
#    Year              Player    mvp  G!  MP!  FG!  3P!  FT!  ORB!  DRB!  TRB!  \
# 0  2024        Jayson Tatum  False   1    1    1    3    1     5     1     1
# 1  2024        Jaylen Brown   True   1    2    2    4    2     5     4     4
# 2  2024        Jrue Holiday  False   1    3    3    4    5     1     3     2
# 3  2024       Derrick White  False   1    4    4    1    3     2     5     5
# 4  2024          Sam Hauser  False   1    6    5    2    6     3     7     6
# 5  2024  Kristaps Porzingis  False   8    8    5    8    4     8     6     7
# 6  2024          Al Horford  False   1    5    7    4    7     3     2     3
# 7  2024    Payton Pritchard  False   1    7    8    7    8     7     8     8
#
#    AST!  STL!  BLK!  TOV!  PF!  PTS!  FG%!  3P%!  FT%!
# 0     1     4     4     8    5     1     7     5     4
# 1     2     1     3     7    8     2     5     6     6
# 2     3     5     4     6    7     3     2     3     1
# 3     4     2     1     5    5     4     6     4     1
# 4     7     6     7     1    3     5     4     1     1
# 5     8     8     1     2    1     6     1     7     5
# 6     4     2     4     3    4     7     3     2     7
# 7     6     6     7     3    2     8     8     8     8

# %% [markdown]
# We'll try to pull a random year's url, to see what that table looks like.

# %%
top_table(FULL_DF['url'][55],8)
# Out:
#    Year           Player    mvp  G!  MP!  FG!  3P!  FT!  ORB!  DRB!  TRB!  \
# 0  1969    John Havlicek  False   1    1    1    1    1     1     1     2
# 1  1969        Sam Jones  False   1    4    2    1    3     1     1     6
# 2  1969  Larry Siegfried  False   1    6    3    1    2     1     1     7
# 3  1969       Don Nelson  False   1    7    4    1    3     1     1     3
# 4  1969        Em Bryant  False   1    3    5    1    5     1     1     5
# 5  1969    Bailey Howell  False   1    5    5    1    7     1     1     4
# 6  1969     Bill Russell  False   1    1    7    1    6     1     1     1
# 7  1969      Tom Sanders  False   8    8    8    1    8     1     1     8
#
#    AST!  STL!  BLK!  TOV!  PF!  PTS!  FG%!  3P%!  FT%!
# 0     2     1     1     1    4     1     3     1     4
# 1     5     1     1     1    2     2     1     1     5
# 2     3     1     1     1    7     3     7     1     2
# 3     6     1     1     1    3     4     4     1     6
# 4     4     1     1     1    5     5     5     1     3
# 5     7     1     1     1    8     6     8     1     7
# 6     1     1     1     1    6     7     6     1     8
# 7     8     1     1     1    1     8     2     1     1

# %% [markdown]
# Here will be the dataframe we will base our learning upon.  It is the top eight highest scoring players of each winning NBA champion.

# %%
# full top 8
FULL_TOP_8 = top_table(FULL_DF['url'][0],8)
for i in tqdm(range(len(FULL_DF['url'])-1)):
    FULL_TOP_8 = pd.concat([FULL_TOP_8,top_table(FULL_DF['url'][i+1],8)],axis=0)
df.reset_index(drop=True).to_csv('output/top8_full.csv')
FULL_TOP_8 = FULL_TOP_8.reset_index(drop=True)
# Out:
# 100%|██████████| 55/55 [00:00<00:00, 113.79it/s]

# %%
FULL_TOP_8.sample(5)
# Out:
#      Year            Player    mvp  G!  MP!  FG!  3P!  FT!  ORB!  DRB!  TRB!  \
# 411  1973       Earl Monroe  False   1    4    4    1    3     1     1     7
# 361  1979    Dennis Johnson   True   1    1    2    1    2     5     3     4
# 327  1984      Scott Wedman  False   8    8    8    2    8     5     6     5
# 394  1975        Phil Smith  False   1    5    4    1    2     4     7     8
# 192  2000  Shaquille O'Neal   True   1    1    1    7    1     1     1     1
#
#      AST!  STL!  BLK!  TOV!  PF!  PTS!  FG%!  3P%!  FT%!
# 411     2     1     1     1    2     4     1     1     6
# 361     2     1     2     7    5     2     6     1     2
# 327     6     8     6     2    1     8     3     2     8
# 394     3     7     2     1    7     3     5     1     4
# 192     5     2     1     8    6     1     1     7     8

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# Ok, now we get into the ML classification.

# %% [markdown]
# We will working with the scikit_learn infrastructure to perform our analysis.

# %% [markdown]
# ### Quick and Dirty

# %% [markdown]
# First, do we even need machine learning to answer this question?

# %% [markdown]
# To benchmark the success of our machine learning model, we would like a control to compare our results against.  There is one intuitive control, and one more closely replicating our process.

# %% [markdown]
# The first would simply be, is the MVP the player who totalled the most combined points, rebounds, and assists.  Now, while it's intuitive, it's answering a slightly different question.  \
# \
# The question it is answering is "who should have won Finals MVP among these players?" which is certainly a valid question.  But from the way we have framed our data, we are answering the question, given player X's performance relative to all players in set Y, how deserving is player X to win Finals MVP?

# %%
def just_points(url):
    df = clean_table(url)
    player_max = df['PTS'].idxmax()
    return df.loc[player_max, 'Player']

# %%
def points_rebounds_assists(url):
    df = clean_table(url)
    df['dirty'] = df.apply(lambda row: row['PTS']+row['TRB']+row['AST'], axis=1)
    player_max = df['dirty'].idxmax()
    return df.loc[player_max, 'Player']

# %%
def control_trial(dirty_method):
    y_pred = merged_table()['url'].apply(lambda x: dirty_method(x))
    y_true = merged_table()[:-1][['Yr','Team','Player']]
    y_true = y_true.rename(columns={'Yr': 'Year'})
    y_true['Team'] = y_true['Team'].apply(lambda x: x[:x.find(" (")])
    y_true['Guess'] = y_pred
    y_true['Correct'] = y_true['Player'] == y_true['Guess']
    return y_true

# %%
just_points_output = control_trial(just_points)
ppg_trb_ast_output = control_trial(points_rebounds_assists)
ppg_trb_ast_output.head(5)
# Out:
#    Year                   Team                 Player                  Guess  \
# 0  2024         Boston Celtics           Jaylen Brown           Jayson Tatum
# 1  2023         Denver Nuggets           Nikola Jokic           Nikola Jokic
# 2  2022  Golden State Warriors          Stephen Curry          Stephen Curry
# 3  2021        Milwaukee Bucks  Giannis Antetokounmpo  Giannis Antetokounmpo
# 4  2020     Los Angeles Lakers           LeBron James           LeBron James
#
#    Correct
# 0    False
# 1     True
# 2     True
# 3     True
# 4     True

# %% [markdown]
# So how did we do? -- Let's take a look.

# %%
print("Just points:")
print(just_points_output['Correct'].describe())
print("\nPoints, rebounds, assists:")
print(ppg_trb_ast_output['Correct'].describe())
# Out:
# Just points:
# count       55
# unique       2
# top       True
# freq        43
# Name: Correct, dtype: object
#
# Points, rebounds, assists:
# count       55
# unique       2
# top       True
# freq        41
# Name: Correct, dtype: object

# %% [markdown]
# So we have got 41 and 43 respectively out of 55.  That's not horrible, but promising that we can hope to do better.  Funny that more information led us further from the truth.

# %%
print(round(41/55,2))
print(round(43/55,2))
# Out:
# 0.75
# 0.78

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# The meat of this notebook... hopefully.

# %% [markdown]
# A reminder that FULL_TOP_8 is our global variable (I know) dataframe that we can reference to keep a nice storage of the top 8 scoring players of each team.

# %% [markdown]
# First we split the dataset into data to learn on, and the data label itself.

# %%
X = FULL_TOP_8.drop(['Year','Player','mvp'],axis=1)
y = FULL_TOP_8['mvp']

# %% [markdown]
# Now we split the data into 70% being training data, and 30% being testing.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, 

                                           stratify = y, random_state=2022)
smote = SMOTE(sampling_strategy='minority')
X_train_SMOTE, y_train_SMOTE = smote.fit_resample(X_train,y_train)

# %% [markdown]
# You might notice "SMOTE".  And you might ask, what is that?  Well "synthetic minority oversampling technique".  Think affirmative action.  I'm just joking.  Basically in our dataset, because we're trying to label the MVP, and there is only one MVP awarded each season to a roster of 15 or so players (here we cut down to 8 players to remedy a bit), it follows that in our case that only about 12% of the data will be labeled "MVP". \
# \
# This is a bit of a problem because our model will be much more comfortable assigning the "non-mvp" label, simply because it's more used to doing so, and being rewarded for doing so. \
# \
# Enter SMOTE.  For each Finals MVP, say Lebron James it looks at its nearest similar neighbors (stat wise), say Larry Bird, and Ervin Magic Johnson are two, and creates datapoints in between these players.  Say the fake data points would then be named "Larry Magic James" or "Lebron Johnson", etc. with corresponding averaged stats.

# %% [markdown]
# Notice how we are able to train train on significantly more "True" Finals_MVP cases with our SMOTE implementation.

# %%
pd.DataFrame(y_test).value_counts()
# Out:
# mvp
# False    118
# True      17
# dtype: int64

# %%
y_train_SMOTE.value_counts()
# Out:
# False    275
# True     275
# Name: mvp, dtype: int64

# %% [markdown]
# Ok, now for K-Fold.  If you're unfamiliar, basically we want to label every point with a prediction.  But because we train on a portion of our data, and then only make predictions on a smaller test set, we're stuck a bit.  Enter K-Fold. \
# \
# If your testing size is set to 20% of your entire dataset, K Fold then goes through 1/.20, so 5 iterations of splitting into testing and training, ensuring each data point is included in the test set once. \
# \
# I didn't invent it, but I'm happy to take credit.

# %%
logistic_classifier = LogisticRegression(max_iter=200)
smote = SMOTE(sampling_strategy='minority')
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
# just book-keeping how we collect results
oof_predictions = np.zeros((X.shape[0], 2))
oof_binary = np.zeros(X.shape[0])

# ACTUAL MACHINE LEARNING
# test_index is jumping from first 20%, to then 20% through 40%, etc.
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    # Apply SMOTE to the training data
    X_train_res, y_train_res = smote.fit_resample(X_train, y_train)
    
    # Train the model on the balanced data
    logistic_classifier.fit(X_train_res, y_train_res)
    
    # Predict probabilities for the validation set
    oof_predictions[test_index] = logistic_classifier.predict_proba(X_test)
    oof_binary[test_index] = y_test

# more book-keeping
oof_df = pd.DataFrame(oof_predictions[:,1], columns=['prob_mvp']).round(2)
output = pd.concat([FULL_TOP_8[['Year','Player','mvp']].reset_index(drop=True), oof_df], axis=1)
final_predictions = oof_predictions[:,1].round(0)
output['Guess'] = final_predictions
output['Correct'] = final_predictions == output['mvp']

# %%
output.sample(5)
# Out:
#      Year          Player    mvp  prob_mvp  Guess  Correct
# 195  2000      Ron Harper  False      0.01    0.0     True
# 282  1989  Vinnie Johnson  False      0.00    0.0     True
# 302  1987      A.C. Green  False      0.00    0.0     True
# 409  1973    Walt Frazier  False      0.92    1.0    False
# 199  2000      A.C. Green  False      0.00    0.0     True

# %% [markdown]
# Ok, I'm intentionally leaving sparser comments for the above code, because I think it deserves to be digested in a large bite.  That is the learning right there.

# %% [markdown]
# Time to look at the results!

# %%
print("Classification Report:")
print(classification_report(oof_binary, final_predictions))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.92      0.94       393
#          1.0       0.57      0.78      0.66        55
#
#     accuracy                           0.90       448
#    macro avg       0.77      0.85      0.80       448
# weighted avg       0.92      0.90      0.91       448

# %% [markdown]
# Ok, what did this all mean?  Well accuracy may jump out at 91%, but that is deceivingly high.  That includes its prediction for all players, mvp and non-mvp.

# %% [markdown]
# For the 1.0 class, that we care about \
# \
# Precision = (# actual Finals MVPs predicted to be Finals MVP) / (# predicted Finals MVPs) \
# \
# Recall = (# actual Finals MVPs predicted to be Finals MVP) / (# actual Finals MVPs)

# %% [markdown]
# So what we care about above is recall, being able to label Finals MVPs. \
# \
# So on my latest run of this model, I got 82% accuracy (yours likely will differ each time you rerun), so not perfect but better than our "quick and dirty" model.

# %% [markdown]
# What is that 18% we're missing?  And how does it compare to those we missed with our simplified approach? Well let's take a look.

# %%
print("Our quick and dirty mistakes")
mistakes = ppg_trb_ast_output[ppg_trb_ast_output['Correct']== False]
mistakes = pd.merge(mistakes, output, on=['Year','Player'], how='left')
mistakes = mistakes.drop(columns=['Correct_y','Guess_y','mvp'])
mistakes.columns = ['Year', 'Team', 'MVP', 'Guess', 'Correct?',
       'prob_mvp']
mistakes
# Out:
# Our quick and dirty mistakes
#     Year                   Team               MVP                Guess  \
# 0   2024         Boston Celtics      Jaylen Brown         Jayson Tatum
# 1   2015  Golden State Warriors    Andre Iguodala        Stephen Curry
# 2   2014      San Antonio Spurs     Kawhi Leonard           Tim Duncan
# 3   2008         Boston Celtics       Paul Pierce        Kevin Garnett
# 4   2007      San Antonio Spurs       Tony Parker           Tim Duncan
# 5   2004        Detroit Pistons  Chauncey Billups     Richard Hamilton
# 6   1988     Los Angeles Lakers      James Worthy        Magic Johnson
# 7   1981         Boston Celtics    Cedric Maxwell           Larry Bird
# 8   1980     Los Angeles Lakers     Magic Johnson  Kareem Abdul-Jabbar
# 9   1979    Seattle SuperSonics    Dennis Johnson         Gus Williams
# 10  1978     Washington Bullets        Wes Unseld          Elvin Hayes
# 11  1976         Boston Celtics       Jo Jo White          Dave Cowens
# 12  1973        New York Knicks       Willis Reed     Dave DeBusschere
# 13  1970        New York Knicks       Willis Reed         Walt Frazier
#
#     Correct?  prob_mvp
# 0      False      0.01
# 1      False      0.75
# 2      False      0.84
# 3      False      0.75
# 4      False      0.64
# 5      False      0.96
# 6      False      0.04
# 7      False      0.99
# 8      False      0.98
# 9      False      0.12
# 10     False      0.00
# 11     False      0.98
# 12     False      0.00
# 13     False      0.00

# %%
print("Our ML mistakes")
ml_mistakes_all = ml_mistakes.rename(columns={'Player':'MVP'})
ml_mistakes = ml_mistakes_all[(ml_mistakes_all['mvp']== True) & (ml_mistakes_all['Correct']== False)]
ml_mistakes
# Out:
# Our ML mistakes
#      Year             MVP   mvp  prob_mvp  Guess  Correct
# 1    2024    Jaylen Brown  True      0.01    0.0    False
# 120  2009     Kobe Bryant  True      0.45    0.0    False
# 152  2005      Tim Duncan  True      0.17    0.0    False
# 208  1998  Michael Jordan  True      0.11    0.0    False
# 280  1989      Joe Dumars  True      0.28    0.0    False
# 288  1988    James Worthy  True      0.06    0.0    False
# 340  1982   Magic Johnson  True      0.42    0.0    False
# 361  1979  Dennis Johnson  True      0.14    0.0    False
# 374  1978      Wes Unseld  True      0.00    0.0    False
# 410  1973     Willis Reed  True      0.00    0.0    False
# 432  1970     Willis Reed  True      0.00    0.0    False

# %%
print("Mistakes for both ML and simplified")
mistakes_both = pd.merge(mistakes, ml_mistakes[['Year','MVP']], on=['Year','MVP'], how='inner')
mistakes_both
# Out:
# Mistakes for both ML and simplified
#    Year                 Team             MVP             Guess  Correct?  \
# 0  2024       Boston Celtics    Jaylen Brown      Jayson Tatum     False
# 1  1988   Los Angeles Lakers    James Worthy     Magic Johnson     False
# 2  1979  Seattle SuperSonics  Dennis Johnson      Gus Williams     False
# 3  1978   Washington Bullets      Wes Unseld       Elvin Hayes     False
# 4  1973      New York Knicks     Willis Reed  Dave DeBusschere     False
# 5  1970      New York Knicks     Willis Reed      Walt Frazier     False
#
#    prob_mvp
# 0      0.01
# 1      0.04
# 2      0.12
# 3      0.00
# 4      0.00
# 5      0.00

# %% [markdown]
# So while our accuracy is not 100%, we have to consider, that 100% may not be the goal.  Because we are not fitting to a perfectly labeled dataset.  The voters could be wrong.

# %% [markdown]
# ## Decision Tree

# %%
## TODO

# %% [markdown]
# ## Random Forest

# %%
## TODO

# %% [markdown]
# ## Comparative Analysis

# %% [markdown]
# ## Conclusion

# %% [markdown]
# ### Visualizations

# %% [markdown]
# ### Next Steps
